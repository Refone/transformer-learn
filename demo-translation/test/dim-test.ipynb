# %%
import torch
import torch.nn as nn

# %%
embed = nn.Embedding(
    num_embeddings=100,
    embedding_dim=128
)

x = torch.randint(0, 100, (64, 20))
x.shape
# Out:
# torch.Size([64, 20])

# %%
y = embed(x)
y.shape
# Out:
# torch.Size([64, 20, 128])
